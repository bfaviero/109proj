# %%
#%matplotlib inline

import requests
import StringIO
import zipfile
import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting
from dateutil.parser import parse
import datetime
from datetime import timedelta
from utils import *
from process_data import *

# %%
funds = get_funds()

# %%
funds[6].head()
# Out:
#                                   filer  \
# date
# 2001-03-31  TUDOR INVESTMENT CORP ET AL
# 2001-03-31  TUDOR INVESTMENT CORP ET AL
# 2001-03-31  TUDOR INVESTMENT CORP ET AL
# 2001-03-31  TUDOR INVESTMENT CORP ET AL
# 2001-03-31  TUDOR INVESTMENT CORP ET AL
#
#                                              name ticker type  current_shares  \
# date
# 2001-03-31              Becton, Dickinson and Co.    BDX   SH         3192900
# 2001-03-31                     Altria Group, Inc.     MO   SH         2021400
# 2001-03-31  PowerShares QQQ Trust - Unit Series 1    QQQ   SH         2325000
# 2001-03-31                       CareMark RX Inc.    CMX   SH         5096540
# 2001-03-31                       ChoicePoint Inc.    CPS   SH         1745904
#
#             current_value  previous_shares  previous_value  current_percent  \
# date
# 2001-03-31      112773000                0               0           4.9520
# 2001-03-31       95915000                0               0           4.2118
# 2001-03-31       91024000                0               0           3.9970
# 2001-03-31       66459000                0               0           2.9183
# 2001-03-31       59012000                0               0           2.5913
#
#             previous_percent  rank  previous_rank  change_in_shares  \
# date
# 2001-03-31               NaN     1         999999               NaN
# 2001-03-31               NaN     2         999999               NaN
# 2001-03-31               NaN     3         999999               NaN
# 2001-03-31               NaN     4         999999               NaN
# 2001-03-31               NaN     5         999999               NaN
#
#            change_type            sector quarter  year
# date
# 2001-03-31         new       HEALTH CARE       2  2001
# 2001-03-31         new  CONSUMER STAPLES       2  2001
# 2001-03-31         new           FINANCE       2  2001
# 2001-03-31         new       HEALTH CARE       2  2001
# 2001-03-31         new       INDUSTRIALS       2  2001
